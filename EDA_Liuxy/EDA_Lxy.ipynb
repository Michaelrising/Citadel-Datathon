# %%
# read data in APAC_2023_Datasets crash_info_vehicles.csv by python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.append('C:\\Users\\10539\\Desktop\\Datathon')
data = pd.read_csv('../APAC_2023_Datasets/Crashes/crash_info_vehicles.csv')

# %%
Feature = pd.DataFrame()
Feature_fatal = pd.DataFrame()

# %%
Feature_way = pd.DataFrame()

# %%
# do EDA for data 
data.head()
# Out:
#    AVOID_MAN_CD  BODY_TYPE COMM_VEH         CRN  DAMAGE_IND  DVR_PRES_IND  \
# 0           NaN       41.0        N  2012032721         3.0           1.0
# 1           NaN        4.0        N  2012032734         1.0           1.0
# 2           NaN        5.0        N  2012031602         3.0           1.0
# 3           NaN        4.0        N  2012024286         3.0           1.0
# 4           NaN        4.0        N  2012026855         3.0           1.0
#
#    EMERG_VEH_USE_CD  GRADE  IMPACT_POINT INS_IND  ... UNIT_NUM  UNIT_TYPE  \
# 0               NaN    1.0          12.0       Y  ...        1          1
# 1               NaN    1.0          12.0       Y  ...        1          1
# 2               NaN    1.0           2.0       Y  ...        1          1
# 3               NaN    1.0          12.0       Y  ...        1          1
# 4               NaN    1.0           7.0       Y  ...        1          1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284487 entries, 0 to 284486
# Data columns (total 31 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   AVOID_MAN_CD       1854 non-null    float64
#  1   BODY_TYPE          253650 non-null  float64
#  2   COMM_VEH           275469 non-null  object
#  3   CRN                284487 non-null  int64
#  4   DAMAGE_IND         264896 non-null  float64
#  5   DVR_PRES_IND       264167 non-null  float64
#  6   EMERG_VEH_USE_CD   1854 non-null    float64
#  7   GRADE              264852 non-null  float64
#  8   IMPACT_POINT       264961 non-null  float64
#  9   INS_IND            255611 non-null  object
#  10  MAKE_CD            253485 non-null  object
#  11  MODEL_YR           247385 non-null  float64
#  12  OWNER_DRIVER       234085 non-null  float64
#  13  PEOPLE_IN_UNIT     284487 non-null  int64
#  14  PRIN_IMP_PT        1856 non-null    float64
# ...

# %% [markdown]
# ### Avoidance Maneuver Code - only for fatal crashes
#
# 1854致命车祸里面选
#
# 多数是no avoidance maneuver，9不知道是什么
#
# 0 - No avoidance maneuver
#
# 1 - Braking - skid marks evident
#
# 2 - Braking - no skid marks, driver stated
#
# 3 - Braking - other evidence
#
# 4 - Steering - evidence or driver stated
#
# 5 - Steering and braking - evidence or stated
#
# 6 - Other avoidance maneuver
#
# 7 - Inconclusive

# %%
Feature_fatal['AVOID_MAN_CD']=data['AVOID_MAN_CD']

# %%
data['AVOID_MAN_CD'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### Body Type Code
#
# 这个数据但是不知道城市各种车的总数不能用来推断
#
# 最多的是:
#
# - 4 Door sedan or hardtop
# - 15 Large utility; Tahoe; Range Rover; Etc.
# - 09 - Unknown automobile type
# - 51 - Standard pickup
#
#
# 01 - Convertible
#
# 02 - 2-Door sedan, hardtop or coupe
#
# 03 - 3-Door hatch back
#
# 04 - 4-Door sedan or hardtop
#
# 05 - 5-Door sedan or hatch back
#
# 06 - Station wagon. Excluding van and truck-based
#
# 08 - Other automobile type
#
# 09 - Unknown automobile type
#
# 10 - Automobile-based pickup
#
# 11 - Automobile-based panel truck
#
# 12 - Compact utility e.g. Tracker; Cherokee;etc.
#
# 13 - Large limousine
#
# 14 - 3-wheel automobile or auto derivative
#
# 15 - Large utility; Tahoe; Range Rover; Etc.
#
# 16 - Utility Station Wagon
#
# 19 - Unknown utility style body type
#
# 20 - Motorcycle
#
# 21 - Moped
#
# 22 - Three-wheeled motorcycle or moped
#
# 23 - Off-road motorcycle
#
# 24 - ATV - all terrain vehicle
#
# 25 - Mini-bike or motor scooter
#
# 28 - Other motorcycle type
#
# 29 - Unknown motorcycle type
#
# 30 - School bus
#
# 31 - Cross country or inner-city bus(i.e. Greyhound bus)
#
# 32 - Transit bus
#
# 38 - Other bus
#
# 39 - Unknown bus
#
# 40 - Mini-van
#
# 41 - Large van
#
# 42 - Step-in or walk-in van
#
# 43 - Van-based motor home
#
# 44 - Van-based school bus
#
# 45 - Van-based transit bus
#
# 48 - Other type van
#
# 49 - Unknown van type
#
# 50 - Compact pickup
#
# 51 - Standard pickup
#
# 52 - Pickup with slide in camper

# %%
data['BODY_TYPE'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %%
Feature['COMM_VEH']=data['COMM_VEH']

# %%
data['COMM_VEH'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# non commercial 占比大
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Damage Indicator
#
# 车辆损毁程度能够当程度指标
#
# 0 – None
#
# 1 – Minor (Drivable)
#
# 2 - Functional (mod. - may be undrivable
#
# 3 – Disabling (severe – not drivable)
#
# 9 – Unknown

# %%
Feature['DAMAGE_IND']=data['DAMAGE_IND']

# %%
data['DAMAGE_IND'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Driver presence indicator
#
# 重要指标: 驾驶员状态
#
# 1 – Apparently Normal
#
# 2 – Had Been Drinking
#
# 3 – Illegal Drug Use
#
# 4 – Sick
#
# 5 – Fatigue
#
# 6 – Asleep
#
# 7 – Medication
#
# 9 - Unknown

# %%
Feature['DVR_PRES_IND']=data['DVR_PRES_IND']

# %%
data['DVR_PRES_IND'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Special Vehicle use code– only for fatal crashes
#
# 又是相关措施，可以和车辆情况对比
#
# 0 – Not in Emergency Use
#
# 1 – Lights Flashing
#
# 2 – Siren Sounding
#
# 3 – Both Lights and Siren
#
# 9 – Unknown

# %%
Feature_fatal['EMERG_VEH_USE_CD']=data['EMERG_VEH_USE_CD']

# %%
data['EMERG_VEH_USE_CD'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Grade Code
#
# 路段情况: 感觉不明确
#
# 1 – Level Roadway
#
# 2 - Uphill
#
# 3 - Downhill
#
# 4 - Sag or bottom of hill
#
# 5 - Crest or top of hill
#
# 9 - Unknown

# %%
Feature_way['GRADE'] = data['GRADE']

# %%
data['GRADE'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Initial Impact Point
#
# 撞点？有差异主要是正撞和追尾，还有侧面擦，可以再细分成三类+其它
#
# 00 - Non-collision
#
# 01 - 1 O-Clock Position
#
# 02 - 2 O-Clock Position
#
# 03 - 3 O-Clock Position
#
# 04 - 4 O-Clock Position
#
# 05 - 5 O-Clock Position
#
# 06 - 6 O-Clock Position
#
# 07 - 7 O-Clock Position
#
# 08 - 8 O-Clock Position
#
# 09 - 9 O-Clock Position
#
# 10 - 10 O-Clock Position
#
# 11 - 11 O-Clock Position
#
# 12 - 12 O-Clock Position
#
# 13 - Top
#
# 14 - Undercarriage
#
# 15 - Towed Unit
#
# 99 - Unknown

# %%
Feature_way['IMPACT_POINT'] = data['IMPACT_POINT']

# %%
data['IMPACT_POINT'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Insurance Indicator Y/N
#
# 保险，但是不知道保险比例
#
# 0=No & 1=Yes

# %%
data['INS_IND'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### 车品牌
# 但是同样不知道一共多少辆

# %%
data['MAKE_CD'].value_counts()[:10]
# Out:
# FORD    31774
# TOYT    25940
# CHEV    25662
# HOND    22819
# NISS    22544
# DODG    12659
# HYUN    10026
# UNKN     6838
# JEEP     6802
# CHRY     6499
# Name: MAKE_CD, dtype: int64

# %%
Feature['MAKE_CD']

# %%
data['MAKE_CD'].value_counts()
# Out:
# FORD    31774
# TOYT    25940
# CHEV    25662
# HOND    22819
# NISS    22544
#         ...
# VAND        1
# AC          1
# FTWD        1
# PRTA        1
# PONI        1
# Name: MAKE_CD, Length: 134, dtype: int64

# %%
data['MAKE_CD'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### 车型的年份
# 也不知道占比

# %%
data['MODEL_YR'].value_counts()
# Out:
# 2007.0    14428
# 2006.0    14239
# 2008.0    13898
# 2005.0    13572
# 2004.0    13305
#           ...
# 1906.0        1
# 1954.0        1
# 1959.0        1
# 1967.0        1
# 1956.0        1
# Name: MODEL_YR, Length: 80, dtype: int64

# %%
data['MODEL_YR'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Was the vehicle owned by the Driver? If not, who owns the vehicle?
#
# 00 Not Applicable
#
# 01 Private Vehicle Owned/Leased by Driver
#
# 02 Private Vehicle Not Owned/Leased by Driver
#
# 03 Rented Vehicle
#
# 04 State Police Vehicle
#
# 05 PennDOT Vehicle
#
# 06 Other State Gov Veh
#
# 07 Municipal Police Vehicle
#
# 08 Other Municipal Government Vehicle
#
# 09 Federal Gov Veh
#
# 98 Other
#
# 99 Unknown

# %%
data['OWNER_DRIVER'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %%
data['PEOPLE_IN_UNIT'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### 主要碰撞方向
# 只对致命的

# %%
Feature_fatal['PRIN_IMP_PT']=data['PRIN_IMP_PT']

# %%
sum(~np.isnan(data['PRIN_IMP_PT']))
# Out:
# 1856

# %%
data['PRIN_IMP_PT'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Roadway Alignment Code
#
# 1 - Straight
#
# 2 – Curved (expired 1-1-20)
#
# 3 – Curve Left
#
# 4 – Curve Right
#
# 9 - Unknown

# %%
Feature_way['RDWY_ALIGNMENT']=data['RDWY_ALIGNMENT']

# %%
data['RDWY_ALIGNMENT'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Special Usage of the Vehicle
#
# - 12 Comm. passenger carrier
#
# - 46 Van – Passenger (<9)
#
# 00 - Not applicable
# 01 - Fire vehicle
# 02 - Ambulance
# 03 - Police
# 08 - Other emergency vehicle
# 11 - Pupil transport
# 12 - Comm. passenger carrier
# 13 - Taxi
# 14 – Electronic Ride Hailing
# 21 - Tractor trailer
# 22 - Twin trailer
# 23 - Triple trailer
# 31 - Modified vehicle
# 41 - Motorcycle – 2-Wheeled
# 42 - Motorcycle – 3-Wheeled (two rear)
# 43 - Motorcycle – 3-Wheeled (two front)
# 44 - Motorcycle – Moped or Motorized
# Bicycle
# 45 - Bicycle – Electric Assist
# 46 - Van – Passenger (<9)
# 47 - Van – Passenger (9-12)
# 48 - Van – Passenger (15)
# 49 - Van - Cargo
# 99 - Unknown

# %%
data['SPECIAL_USAGE'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### 行驶方向
# 没用明显差异

# %%
data['TRAVEL_DIRECTION'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %%
data['TRAVEL_SPD'].value_counts()
# 离群点去掉
# Out:
# 999.0    121026
# 0.0       48685
# 25.0      18016
# 30.0       8605
# 20.0       8299
#           ...
# 430.0         1
# 73.0          1
# 565.0         1
# 123.0         1
# 645.0         1
# Name: TRAVEL_SPD, Length: 235, dtype: int64

# %%
temp = data['TRAVEL_SPD'].copy(deep=True)
temp[temp<0] = np.nan
temp[temp>200] = np.nan

# %%
data['TRAVEL_SPD'] = temp

# %%
data['TRAVEL_SPD'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### Trailing Vehicle Count

# %%
data['TRL_VEH_CNT'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Under Ride damage indicator– only for fatal crashes
#
# 0 - No under ride or override
#
# 1 - Under ride, compartment intrusion
#
# 2 - Under ride, no compartment intrusion
#
# 3 - Under ride, compartment intrusion unknown
#
# 4 - Override, other vehicle
#
# 9 - Unknown if under ride or override

# %%
data['UNDER_RIDE_IND'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %%
# Unit number assigned to the vehicle or pedestrian
data['UNIT_NUM'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Unit Type
#
# 01 - Motor vehicle in transport
#
# 02 - Legally parked
#
# 03 - Illegally parked
#
# 05 - Hit and run vehicle
#
# 06 - Disabled from a previous crash
#
# 11 - Non-motorized
#
# 21 - Train
#
# 31 - Pedestrian
#
# 32 -Pedestrian Conveyance (Wheelchair,etc.)
#
# 33 – Personal Delivery Device
#
# 51 - Phantom vehicle

# %%
Feature['UNIT_TYPE']=data['UNIT_TYPE']

# %%
# Unit number assigned to the vehicle or pedestrian
data['UNIT_TYPE'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# Vehicle Color Code
#
# 01 – Blue 08- Gold
# 02 – Red 09 – Brown
# 03 – White 10 – Orange
# 04 – Green 11 – Purple
# 05 – Black 12 – Other
# 06 – Yellow 99 - Unknown
# 07 – Silver

# %%
data['VEH_COLOR_CD'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %%
data['VEH_MOVEMENT'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %%
Feature_way['VEH_MOVEMENT']=data['VEH_MOVEMENT']

# %% [markdown]
# ### Vehicle Movement Code
#
# 01 - Going straight
# 02 - Slowing or stopping in lane
# 03 - Stopped in traffic lane
# 04 - Passing or overtaking vehicle
# 05 - Leaving a parked position (expired
# 1-1-20)
# 06 – Parked
# 07 - Entering a parked position (expired
# 1-1-20)
# 08 - Trying to avoid animal, pedestrian,
# object,
# vehicle, etc.
# 09 - Turning right on red
# 10 - Turning right
# 11- Turning left on red
# 12- Turning left
# 13- Making a U-turn
# 14- Backing up
# 15- Changing lanes or merging
# 16- Negotiating Curve Right
# 17- Negotiating curve- left
# 18– Entering Traffic Lane
# 19– Leaving Traffic Lane
# 98- Other
# 99- Unknown

# %%
data['VEH_MOVEMENT'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### Vehicle Position Code
#
# 00- Not applicable (for peds.)
# 01 - Right lane (Curb)
# 02- Right turn lane
# 03- Left lane
# 04- Left turn lane
# 05- Two-direction center turn lane
# 06- Other forward moving lane
# 07- Oncoming traffic lane
# 08- Left of trafficway
# 09- Right of trafficway
# 10- HOV lane
# 11- Shoulder rig
# 12- Shoulder left
# 13-One lane road
# 14– Acceleration/Deceleration Lane
# 98- Other
# 99- Unknown

# %%
Feature_way['VEH_POSITION']=data['VEH_POSITION']

# %%
data['VEH_POSITION'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### Vehicle Registration State

# %%
Feature['VEH_REG_STATE_PA']=(data['VEH_REG_STATE']=='PA' )

# %%
data['VEH_REG_STATE'].value_counts()
# Out:
# PA    211125
# NJ     15952
# ZZ      6065
# DE      3525
# NY      1948
#        ...
# ZI         1
# BS         1
# JA         1
# ML         1
# MB         1
# Name: VEH_REG_STATE, Length: 79, dtype: int64

# %%
data['VEH_REG_STATE'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### Vehicle Role
#
# 0– Non-Collision
# 1– Striking
# 2– Struck
# 3– Striking and Struck

# %%
Feature['VEH_ROLE']=data['VEH_ROLE']

# %%
data['VEH_ROLE'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# ### Vehicle Type
# 车辆类型
#
#
# 01- Automobile
# 02- Motorcycle
# 03- Bus
# 04- Small truck
# 05- Large truck
# 06- SUV
# 07– Van
# 08- Autocycle
# 09- ROV
# 10- Snowmobile
# 11- Farm Equipment
# 12- Construction Equipment
# 13- ATV
# 14– Golf Cart
# 15– Low Speed Vehicle
# 16– Large Limo
# 17– Motor Home (RV)
# 18- Other type special vehicle
# 19- Unknown type special vehicle
# 20- Bicycle
# 21– Other Pedalcycle
# 22– Horse and buggy
# 23- Horse and rider
# 24- Train
# 25– Trolley
# 98- Other
# 99- Unknown

# %%
data['VEH_TYPE'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %%
data['PARTIAL_VIN'].value_counts()
# Out:
# 99999999999    8183
# UNKN0WN          70
# UNK              58
# 4T1BF3EK3BU      52
# 4T1BF3EK7BU      50
#                ...
# 1FTFW1E67BF       1
# 1N6AF0LY2GN       1
# 1FAHP3DN9AW       1
# 1C4PJMLX2KD       1
# CPY254V3100       1
# Name: PARTIAL_VIN, Length: 113767, dtype: int64

# %% [markdown]
# ### Body Type Code interpreted by VINA software
# MAT- All Terrain
# MEN- Enduro
# MMK- Mini Bike
# MMM- Mini Moto Cross
# MMP- Moped
# MMR- Mini Road / Trail
# MMS- Motor Scooter
# MMX- Moto Cross
# MMY- Mini Cycle
# MRC- Racer
# MRS- Road / Street
# MRT- Road / Trail
# MT- Dirt
# MTL- Trail / Dirt
# MTR- Trail
# P2D- Sedan 2 Dr.
# P2F- Formal Hardtop 2 Dr.
# P2H- Hatchback 2 Dr.
# P2L- Liftback 3 Dr.
# P2P- Pillard Hardtop 2 Dr.
# P2T- Hardtop 2 Dr.
# P4W- Wagon 4 Dr.
# P5D- Sedan 5 Dr.
# PAM- Ambulance
# PCB- Cab & Chassis (Luv)
# PCP- Coupe
# PCV- Convertible (Jeep)
# PHB- Hatchback
# PHR- Hearse
# PHT- Hardtop
# PIN- Incomplete Passenger
# PLB- Liftback
# PLM- Limousine
# PNB- Notchback
# PPK- Pickup
# PPN- Panel
# PRD- Roadster
# PSB- Sport Hatchback
# PSC- Sport Coupe
# T3C- 3 Dr. Extended Cab Pickup
# T4B- 4 Dr. Extended Cab / Chassis
# T4C- 4 Dr. Extended Cab Pickup
# T4W- 4 Dr. Wagon / Sport Utility
# T8V- 8 Passenger Sport Van
# TAC- Auto Carrier
# TAR- Armored Truck
# TBU- Bus
# TCB- Chassis and Cab
# TCC- Conventional Cab
# TCG- Cargo Van
# TCH- Crew Chassis
# TCL- Club Chassis
# TCM- Concrete or Transit Mixer
# TCR- Crane
# TCS- Super Cab / Chassis Pickup
# TCU- Custom Pickup
# TCV- Convertible (Jeep Commando,
# Suzuki
# Samurai,etc)
# TCW- Crew Pickup
# TCY- Cargo Cutaway
# TDP- Dump
# TDS- Truck, Tractor (diesel)
# TEC- Extended Cargo Van
# TES- Extended Sport Van
# TEV- Ext Van
# TEW- Extended Window Van
# TFB- Flatbed or Platform
# TFC- Forward Control (Land Rover)
# TFT- Fire Truck
# TGG- Garbage or Refuse
# TGL- Gliders
# TGN- Grain
# THO- Hopper
# TIC- Incomplete Chassis
# TIE- Incomplete External Van
# TLG- Logger
# TLL- Suburban & Carry All
# TMH- Motorized Home
# TMP- Multi-purpose
# TMV- Maxi Van
# TMW- Maxi Wagon
# TMY- Motorized Cutaway
# TPC- Club Cab Pickup
# TPD- Parcel Delivery
# TPK- Pickup
# TPM- Pickup with Camper mounted on
# bed
# TPN- Panel
# TPS- Super Cab Pickup
# TRD- Roadster (Jeep, Jeep
# Commando)
# TS1- one Seat
# TS2- Two Seat
# TSN- Step Van
# TSP- Sport Pickup
# TST- Stake or Rack
# TSV- Sports Van
# TSW- Station Wagon (Jeep Wagoneer,
# Dodge
# Sportsman)
# TTB- Tilt Cab
# TTL- Tilt Tandem
# TTM- Tandem
# TTN- Tank
# TTR- Tractor Truck (Gasoline)
# TUT- Utility (Blazer, Jimmy, Scout, etc.)
# TVC- Van Camper
# TVD- Display Van
# TVN- Van
# TVT- Vanette (including Metro and
# Handy Van)
# TVW- Window Van
# TWK- Tow Truck Wrecker
# TWW- Wide Wheel Wagon
# TXT- Travelall
# TYY– Cutaway

# %%
data['VINA_BODY_TYPE_CD'].value_counts()
# Out:
# P4D    111861
# PUT     28681
# T4W     24835
# PCP      8178
# T        6802
#         ...
# TCL         1
# TDP         1
# PSD         1
# P4L         1
# MTL         1
# Name: VINA_BODY_TYPE_CD, Length: 83, dtype: int64

# %%
data['VINA_BODY_TYPE_CD'].value_counts().plot(kind='bar', figsize=(10,5),\
                                        title='Crash Date', color='red',\
                                        fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')
# Out:
# <AxesSubplot:title={'center':'Crash Date'}>

# %% [markdown]
# data['MODEL_YR'].value_counts().plot(kind='bar', figsize=(10,5),\
#                                         title='Crash Date', color='red',\
#                                         fontsize=20, rot=90, grid=True, legend=True, label='Crash Date')

# %%
data.columns
# Out:
# Index(['AVOID_MAN_CD', 'BODY_TYPE', 'COMM_VEH', 'CRN', 'DAMAGE_IND',
#        'DVR_PRES_IND', 'EMERG_VEH_USE_CD', 'GRADE', 'IMPACT_POINT', 'INS_IND',
#        'MAKE_CD', 'MODEL_YR', 'OWNER_DRIVER', 'PEOPLE_IN_UNIT', 'PRIN_IMP_PT',
#        'RDWY_ALIGNMENT', 'SPECIAL_USAGE', 'TRAVEL_DIRECTION', 'TRAVEL_SPD',
#        'TRL_VEH_CNT', 'UNDER_RIDE_IND', 'UNIT_NUM', 'UNIT_TYPE',
#        'VEH_COLOR_CD', 'VEH_MOVEMENT', 'VEH_POSITION', 'VEH_REG_STATE',
#        'VEH_ROLE', 'VEH_TYPE', 'PARTIAL_VIN', 'VINA_BODY_TYPE_CD'],
#       dtype='object')

# %%
# 是否商用、车辆损伤程度、驾驶人状态、车辆状态、是否PA登记、本车过失(struck/striking)
Feature
# Out:
#        COMM_VEH  DAMAGE_IND  DVR_PRES_IND  UNIT_TYPE  VEH_REG_STATE_PA  \
# 0             N         3.0           1.0          1              True
# 1             N         1.0           1.0          1              True
# 2             N         3.0           1.0          1             False
# 3             N         3.0           1.0          1              True
# 4             N         3.0           1.0          1              True
# ...         ...         ...           ...        ...               ...
# 284482        N         3.0           2.0          2              True
# 284483        N         9.0           1.0          1             False
# 284484        N         9.0           1.0          1              True
# 284485        N         1.0           1.0          1              True
# 284486        N         9.0           1.0          1              True
#
#         VEH_ROLE
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ...

# %%
temp = Feature_fatal.apply(lambda x:np.isnan(x).all(),axis=1)
temp = ~temp

# %%
Feature['isFatal']=temp

# %%
sum(temp)
# Out:
# 1860

# %%
# 致命车祸信息: 手动制动措施、紧急信号使用、致命撞击方向
Feature_fatal
# Out:
#         AVOID_MAN_CD  EMERG_VEH_USE_CD  PRIN_IMP_PT
# 0                NaN               NaN          NaN
# 1                NaN               NaN          NaN
# 2                NaN               NaN          NaN
# 3                NaN               NaN          NaN
# 4                NaN               NaN          NaN
# ...              ...               ...          ...
# 284482           NaN               NaN          NaN
# 284483           NaN               NaN          NaN
# 284484           NaN               NaN          NaN
# 284485           NaN               NaN          NaN
# 284486           NaN               NaN          NaN
#
# [284487 rows x 3 columns]

# %%
# 道路信息: 上下坡、车祸撞击方向、道路方向、车辆行驶方式、所在车道
Feature_way
# Out:
#         GRADE  IMPACT_POINT  RDWY_ALIGNMENT  VEH_MOVEMENT  VEH_POSITION
# 0         1.0          12.0             3.0          17.0           1.0
# 1         1.0          12.0             1.0          12.0           3.0
# 2         1.0           2.0             2.0          15.0           3.0
# 3         1.0          12.0             1.0           1.0           1.0
# 4         1.0           7.0             1.0           1.0           3.0
# ...       ...           ...             ...           ...           ...
# 284482    1.0           6.0             1.0           6.0           1.0
# 284483    1.0          99.0             1.0           1.0          99.0
# 284484    1.0           6.0             1.0           3.0           1.0
# 284485    1.0           1.0             1.0          12.0          13.0
# 284486    1.0           6.0             1.0           3.0           1.0
#
# [284487 rows x 5 columns]

# %%
Feature['CRN']=data['CRN']
Feature_fatal['CRN']=data['CRN']
Feature_way['CRN']=data['CRN']

# %%
Feature.to_csv('../EDA_Liuxy/Vehicle_features/Feature.csv')
Feature_fatal.to_csv('../EDA_Liuxy/Vehicle_features/Feature_fatal.csv')
Feature_way.to_csv('../EDA_Liuxy/Vehicle_features/Feature_wat.csv')
